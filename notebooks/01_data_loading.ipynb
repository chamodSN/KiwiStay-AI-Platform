# %%
import pandas as pd
import geopandas as gpd
pd.set_option('display.max_rows', None)

# %%
listings = pd.read_csv("../data/raw/listings.csv.gz")
neighbourhoods = pd.read_csv("../data/raw/neighbourhoods.csv")
neighbourhoods_geo = gpd.read_file("../data/raw/neighbourhoods.geojson")

# %%
listings.shape
# Out:
# (46321, 85)

# %%
listings.columns.tolist()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_searched',
#  'last_scraped',
#  'source',
#  'name',
#  'description',
#  'neighborhood_overview',
#  'picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bathrooms_text',
#  'bedrooms',
#  'beds',
#  'amenities',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
# ...

# %%
print(listings.isnull().sum().sort_values(ascending=False))
# Out:
# license                                         46321
# region_parent_parent_name                       46321
# region_parent_parent_id                         46321
# requires_license                                46321
# calendar_updated                                46321
# host_neighbourhood                              46246
# host_about                                      24494
# neighborhood_overview                           23782
# neighbourhood                                   23782
# host_response_rate                              10018
# host_response_time                              10018
# host_location                                    9818
# host_acceptance_rate                             6492
# review_scores_communication                      5103
# review_scores_accuracy                           5103
# review_scores_checkin                            5103
# review_scores_value                              5103
# ...

# %%
(listings.isnull().mean() * 100).sort_values(ascending=False)
# Out:
# license                                         100.000000
# region_parent_parent_name                       100.000000
# region_parent_parent_id                         100.000000
# requires_license                                100.000000
# calendar_updated                                100.000000
# host_neighbourhood                               99.838086
# host_about                                       52.878824
# neighborhood_overview                            51.341724
# neighbourhood                                    51.341724
# host_response_rate                               21.627340
# host_response_time                               21.627340
# host_location                                    21.195570
# host_acceptance_rate                             14.015241
# review_scores_communication                      11.016602
# review_scores_accuracy                           11.016602
# review_scores_checkin                            11.016602
# ...

# %%
listings.head(5)
# Out:
#                     id                                       listing_url  \
# 0  1419869766929384483  https://www.airbnb.com/rooms/1419869766929384483
# 1  1417531189274342484  https://www.airbnb.com/rooms/1417531189274342484
# 2  1352305286886592525  https://www.airbnb.com/rooms/1352305286886592525
# 3             29438313             https://www.airbnb.com/rooms/29438313
# 4  1447387314700756673  https://www.airbnb.com/rooms/1447387314700756673
#
#         scrape_id last_searched last_scraped           source  \
# 0  20250704005853           NaN   2025-07-04  previous scrape
# 1  20250704005853    2025-07-04   2025-07-05   country scrape
# 2  20250704005853    2025-07-04   2025-07-04   country scrape
# 3  20250704005853    2025-07-04   2025-07-04   country scrape
# 4  20250704005853    2025-07-04   2025-07-04   country scrape
#
#                                     name  \
# 0                        Cozy Queen Room
# 1                Cozy Apartment for Rent
# ...

# %%
listings['price'].head(5)
# Out:
# 0        NaN
# 1    $120.00
# 2    $315.00
# 3    $603.00
# 4    $159.00
# Name: price, dtype: str

# %%
listings['host_neighbourhood'].nunique()
# Out:
# 43

# %%
listings['neighbourhood'].nunique()
# Out:
# 1996

# %%
listings['neighborhood_overview'].nunique()
# Out:
# 18835

# %%
neighbourhoods.shape
# Out:
# (239, 2)

# %%
neighbourhoods_geo.head()
# Out:
#             neighbourhood neighbourhood_group  \
# 0            Waipaoa Ward   Gisborne District
# 1       Tawhiti-Uawa Ward   Gisborne District
# 2  Taruheru-Patutahi Ward   Gisborne District
# 3           Gisborne Ward   Gisborne District
# 4     Wairoa General Ward     Wairoa District
#
#                                             geometry
# 0  MULTIPOLYGON (((177.29832 -38.40158, 177.34641...
# 1  MULTIPOLYGON (((178.34318 -38.37897, 178.34336...
# 2  MULTIPOLYGON (((177.88188 -38.62445, 177.8821 ...
# 3  MULTIPOLYGON (((178.04868 -38.70512, 178.04876...
# 4  MULTIPOLYGON (((177.87094 -39.27634, 177.87097...

# %%
listings.dtypes
# Out:
# id                                                int64
# listing_url                                         str
# scrape_id                                         int64
# last_searched                                       str
# last_scraped                                        str
# source                                              str
# name                                                str
# description                                         str
# neighborhood_overview                               str
# picture_url                                         str
# host_id                                           int64
# host_url                                            str
# host_name                                           str
# host_since                                          str
# host_location                                       str
# host_about                                          str
# host_response_time                                  str
# ...
