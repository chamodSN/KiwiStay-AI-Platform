# %% [markdown]
# NZ seasons are flipped, so Feb = peak summer, Apr = early autumn.

# %%
import pandas as pd

# %%
df_sum_feb = pd.read_csv("../data/raw/listings_summary_feb2026.csv")
df_sum_apr = pd.read_csv("../data/raw/listings_summary_apr2026.csv")
df_feb = pd.read_csv("../data/raw/listings_feb2026.csv.gz")
df_apr = pd.read_csv("../data/raw/listings_apr2026.csv.gz")

# %%
df_sum_feb.shape
# Out:
# (48692, 18)

# %%
df_sum_feb.columns.tolist()
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'number_of_reviews_ltm',
#  'license']

# %%
df_sum_feb.dtypes
# Out:
# id                                  int64
# name                                  str
# host_id                             int64
# host_name                             str
# neighbourhood_group                   str
# neighbourhood                         str
# latitude                          float64
# longitude                         float64
# room_type                             str
# price                             float64
# minimum_nights                    float64
# number_of_reviews                   int64
# last_review                           str
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                           float64
# dtype: object

# %%
df_sum_feb.head(3)
# Out:
#                     id                                             name  \
# 0  1065244682287350993                                     Totara Ridge
# 1             43834420  Two Bedroom Access Apartment @ Riverlodge Motel
# 2   650824893416631133              HOT TUB 4 bdr lake/town 5 min drive
#
#      host_id          host_name        neighbourhood_group      neighbourhood  \
# 0  120675713            Melanie           Rotorua District  Area Outside Ward
# 1  342336273  Riverlodge Nelson                Nelson City  Area Outside Ward
# 2  129957281            Brendan  Queenstown-Lakes District        Wanaka Ward
#
#    latitude   longitude        room_type  price  minimum_nights  \
# 0 -38.16076  176.301700  Entire home/apt    NaN             1.0
# 1 -41.26832  173.287260  Entire home/apt    NaN             1.0
# 2 -44.68137  169.157915  Entire home/apt    NaN             1.0
#
#    number_of_reviews last_review  reviews_per_month  \
# ...

# %%
df_sum_apr.shape
# Out:
# (48951, 18)

# %%
df_sum_apr.columns.tolist()
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'number_of_reviews_ltm',
#  'license']

# %%
df_sum_apr.dtypes
# Out:
# id                                  int64
# name                                  str
# host_id                             int64
# host_name                             str
# neighbourhood_group                   str
# neighbourhood                         str
# latitude                          float64
# longitude                         float64
# room_type                             str
# price                             float64
# minimum_nights                    float64
# number_of_reviews                   int64
# last_review                           str
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                           float64
# dtype: object

# %%
df_sum_apr.head(3)
# Out:
#       id                                name  host_id        host_name  \
# 0  36194            The Wharf Hub - a voyage   128489            Lloyd
# 1  46071                              Kamahi   202747            Donna
# 2  51362  PORTAGE HEIGHTS MARLBOROUGH SOUNDS   236005  Ralph & Cynthia
#
#     neighbourhood_group            neighbourhood  latitude  longitude  \
# 0      Ōpōtiki District    Waioeka-Waiotahi Ward -37.99937  177.28239
# 1        Taupo District   Turangi-Tongariro Ward -38.90862  175.75285
# 2  Marlborough District  Marlborough Sounds Ward -41.19326  174.03374
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room  150.0             1.0                 12  2017-02-26
# 1  Entire home/apt  360.0             2.0                 29  2025-04-21
# 2     Private room  343.0             2.0                 77  2026-04-05
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# ...

# %%
df_feb.shape
# Out:
# (48692, 85)

# %%
df_feb.columns.tolist()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_searched',
#  'last_scraped',
#  'source',
#  'name',
#  'description',
#  'neighborhood_overview',
#  'picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bathrooms_text',
#  'bedrooms',
#  'beds',
#  'amenities',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
# ...

# %%
print(df_feb.dtypes.to_string())
# Out:
# id                                                int64
# listing_url                                         str
# scrape_id                                         int64
# last_searched                                       str
# last_scraped                                        str
# source                                              str
# name                                                str
# description                                         str
# neighborhood_overview                           float64
# picture_url                                         str
# host_id                                           int64
# host_url                                            str
# host_name                                           str
# host_since                                      float64
# host_location                                       str
# host_about                                          str
# host_response_time                              float64
# ...

# %%
df_feb.head(3)
# Out:
#                     id                                       listing_url  \
# 0  1065244682287350993  https://www.airbnb.com/rooms/1065244682287350993
# 1             43834420             https://www.airbnb.com/rooms/43834420
# 2   650824893416631133   https://www.airbnb.com/rooms/650824893416631133
#
#         scrape_id last_searched last_scraped          source  \
# 0  20260213082401    2026-02-13   2026-02-16  country scrape
# 1  20260213082401    2026-02-13   2026-02-16  country scrape
# 2  20260213082401    2026-02-13   2026-02-16  country scrape
#
#                                               name  \
# 0                                     Totara Ridge
# 1  Two Bedroom Access Apartment @ Riverlodge Motel
# 2              HOT TUB 4 bdr lake/town 5 min drive
#
#                                          description  neighborhood_overview  \
# 0  Soak up the panoramic views from this peaceful...                    NaN
# ...

# %%
df_apr.shape
# Out:
# (48951, 94)

# %%
df_apr.columns.tolist()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_searched',
#  'last_scraped',
#  'source',
#  'name',
#  'description',
#  'neighborhood_overview',
#  'picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'hosts_time_as_user_years',
#  'hosts_time_as_user_months',
#  'hosts_time_as_host_years',
#  'hosts_time_as_host_months',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bathrooms_text',
#  'bedrooms',
#  'beds',
#  'amenities',
#  'price',
#  'price_quote_checkin_date',
#  'price_quote_checkout_date',
#  'price_quote_total_price',
# ...

# %%
print(df_apr.dtypes.to_string())
# Out:
# id                                                int64
# listing_url                                         str
# scrape_id                                         int64
# last_searched                                       str
# last_scraped                                        str
# source                                              str
# name                                                str
# description                                         str
# neighborhood_overview                           float64
# picture_url                                         str
# host_id                                           int64
# host_url                                            str
# host_name                                           str
# host_since                                      float64
# hosts_time_as_user_years                        float64
# hosts_time_as_user_months                       float64
# hosts_time_as_host_years                        float64
# ...

# %%
df_apr.head(3)
# Out:
#       id                         listing_url       scrape_id last_searched  \
# 0  36194  https://www.airbnb.com/rooms/36194  20260416055825    2026-04-16
# 1  46071  https://www.airbnb.com/rooms/46071  20260416055825    2026-04-16
# 2  51362  https://www.airbnb.com/rooms/51362  20260416055825    2026-04-16
#
#   last_scraped          source                                name  \
# 0   2026-04-22  country scrape            The Wharf Hub - a voyage
# 1   2026-04-22  country scrape                              Kamahi
# 2   2026-04-22  country scrape  PORTAGE HEIGHTS MARLBOROUGH SOUNDS
#
#                                          description  neighborhood_overview  \
# 0  While many like to stay in our heritage accomm...                    NaN
# 1  Relax, look out at the lake and listen to the ...                    NaN
# 2  Portage Heights lodge,Above Portage Resort, Hi...                    NaN
#
#                                          picture_url  ...  \
# ...

# %%
print(df_sum_feb['price'].dtypes)
print(df_sum_apr['price'].dtypes)
print(df_feb['price'].dtypes)
print(df_apr['price'].dtypes)
# Out:
# float64
# float64
# float64
# str

# %%
print(df_sum_feb['price'].isnull().sum())
print(df_sum_apr['price'].isnull().sum())
print(df_feb['price'].isnull().sum())
print(df_apr['price'].isnull().sum())
# Out:
# 48692
# 3844
# 48692
# 3844

# %%
print(df_sum_feb['price'].head(10))
print(df_sum_apr['price'].head(10))
print(df_feb['price'].head(10))
print(df_apr['price'].head(10))
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# Name: price, dtype: float64
# 0    150.0
# 1    360.0
# 2    343.0
# 3    373.0
# 4    137.0
# 5    137.0
# 6    101.0
# 7    286.0
# 8    206.0
# 9    252.0
# Name: price, dtype: float64
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# Name: price, dtype: float64
# 0    $150.00
# 1    $359.50
# 2    $342.50
# 3    $373.00
# 4    $137.00
# 5    $137.00
# 6    $101.00
# 7    $286.00
# 8    $205.50
# 9    $252.00
# Name: price, dtype: str

# %%
set(df_feb.columns) == set(df_apr.columns)
# Out:
# False

# %%
set(df_feb.columns) - set(df_apr.columns)
# Out:
# set()

# %%
set(df_apr.columns) - set(df_feb.columns)
# Out:
# {'hosts_time_as_host_months',
#  'hosts_time_as_host_years',
#  'hosts_time_as_user_months',
#  'hosts_time_as_user_years',
#  'price_quote_checkin_date',
#  'price_quote_checkout_date',
#  'price_quote_price_per_night',
#  'price_quote_raw',
#  'price_quote_total_price'}

# %%
print(df_feb.isnull().sum().to_string())
# Out:
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_searched                                    1900
# last_scraped                                        0
# source                                              0
# name                                                0
# description                                       411
# neighborhood_overview                           48692
# picture_url                                         0
# host_id                                             0
# host_url                                            0
# host_name                                           4
# host_since                                      48692
# host_location                                   10687
# host_about                                      24987
# host_response_time                              48692
# ...

# %%
print(df_apr.isnull().sum().to_string())
# Out:
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_searched                                    4863
# last_scraped                                        0
# source                                              0
# name                                                0
# description                                       413
# neighborhood_overview                           48951
# picture_url                                         0
# host_id                                             0
# host_url                                            0
# host_name                                           3
# host_since                                      48951
# hosts_time_as_user_years                            3
# hosts_time_as_user_months                           3
# hosts_time_as_host_years                            3
# ...
